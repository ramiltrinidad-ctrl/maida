# %% [markdown]
# <a href="https://colab.research.google.com/github/ramiltrinidad-ctrl/maida/blob/main/MountGoogleDrive_PracticeShellCommands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import OS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7539/1443762188.py in <cell line: 0>()
# ----> 1 import OS
#
# ModuleNotFoundError: No module named 'OS'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
cd drive
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# '2019 ProdMan Plans - Ramil Trinidad v4.gslides'
# '2022 Breakthrough Sales Account Planning'/
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 10052022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 1H 08032022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 Yr 2022 30Jan2023_RamilReviewed.xlsx'
# '2022 Sales and GP_v14_delinked - DAO Rev & GP.xlsx'
# '2022 SOs for Validation of PS.xlsx'
# '20230313 Request For Proposal (RFP) - Cloud Modernization for Data Platform v4 (2).xlsx'
# '2023 MDI Novare Budget Template - Product and Sales Operations.xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone (1).xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone.xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - FY2024 (Reviewed).xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - Use for Probationary Goals - with IMFeedback.xlsx'
# '2024 Training and Cert Budget Summary - PendingFinanceNego-Approval.xlsx'
# ...

# %%
# !apt-get install -q tree
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (59.7 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
ls
# Out:
# '2019 ProdMan Plans - Ramil Trinidad v4.gslides'
# '2022 Breakthrough Sales Account Planning'/
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 10052022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 1H 08032022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 Yr 2022 30Jan2023_RamilReviewed.xlsx'
# '2022 Sales and GP_v14_delinked - DAO Rev & GP.xlsx'
# '2022 SOs for Validation of PS.xlsx'
# '20230313 Request For Proposal (RFP) - Cloud Modernization for Data Platform v4 (2).xlsx'
# '2023 MDI Novare Budget Template - Product and Sales Operations.xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone (1).xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone.xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - FY2024 (Reviewed).xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - Use for Probationary Goals - with IMFeedback.xlsx'
# '2024 Training and Cert Budget Summary - PendingFinanceNego-Approval.xlsx'
# ...

# %%
cd ../
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
cd ../../
# Out:
# /

# %%
ls
# Out:
# bin@      dev/     lib@     media/  python-apt/         sbin@  tools/
# boot/     etc/     lib32@   mnt/    python-apt.tar.xz*  srv/   usr/
# content/  home/    lib64@   opt/    root/               sys/   var/
# datalab/  kaggle/  libx32@  proc/   run/                tmp/

# %%
cd content/
# Out:
# /content

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd MyDrive
# Out:
# [Errno 2] No such file or directory: 'MyDrive'
# /content

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd sample_data/
# Out:
# /content/sample_data

# %%
ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
cd ../
# Out:
# /content

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd ../../
# Out:
# /

# %%
ls
# Out:
# bin@      dev/     lib@     media/  python-apt/         sbin@  tools/
# boot/     etc/     lib32@   mnt/    python-apt.tar.xz*  srv/   usr/
# content/  home/    lib64@   opt/    root/               sys/   var/
# datalab/  kaggle/  libx32@  proc/   run/                tmp/

# %%
ls /content/drive/MyDrive
# Out:
# '2019 ProdMan Plans - Ramil Trinidad v4.gslides'
# '2022 Breakthrough Sales Account Planning'/
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 10052022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 1H 08032022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 Yr 2022 30Jan2023_RamilReviewed.xlsx'
# '2022 Sales and GP_v14_delinked - DAO Rev & GP.xlsx'
# '2022 SOs for Validation of PS.xlsx'
# '20230313 Request For Proposal (RFP) - Cloud Modernization for Data Platform v4 (2).xlsx'
# '2023 MDI Novare Budget Template - Product and Sales Operations.xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone (1).xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone.xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - FY2024 (Reviewed).xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - Use for Probationary Goals - with IMFeedback.xlsx'
# '2024 Training and Cert Budget Summary - PendingFinanceNego-Approval.xlsx'
# ...

# %%
# !mkdir "/content/drive/My Drive/Sudoku"

# %%
# !mv "/content/drive/My Drive/Sudoku/" "/content/drive/My Drive/Sudoku-Solver/"

# %%
cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
# '2019 ProdMan Plans - Ramil Trinidad v4.gslides'
# '2022 Breakthrough Sales Account Planning'/
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 10052022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 1H 08032022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 Yr 2022 30Jan2023_RamilReviewed.xlsx'
# '2022 Sales and GP_v14_delinked - DAO Rev & GP.xlsx'
# '2022 SOs for Validation of PS.xlsx'
# '20230313 Request For Proposal (RFP) - Cloud Modernization for Data Platform v4 (2).xlsx'
# '2023 MDI Novare Budget Template - Product and Sales Operations.xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone (1).xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone.xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - FY2024 (Reviewed).xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - Use for Probationary Goals - with IMFeedback.xlsx'
# '2024 Training and Cert Budget Summary - PendingFinanceNego-Approval.xlsx'
# ...

# %%
# !mkdir "/content/drive/My Drive/Sudoku-Solver/scripts"

# %%
# !tree "/content/drive/My Drive/Sudoku-Solver" -L 2
# Out:
# /content/drive/My Drive/Sudoku-Solver
# ├── scripts
# ├── src
# │   └── Sudoku-Solver
# └── tests
#
# 4 directories, 0 files

# %%
ls
# Out:
# '2019 ProdMan Plans - Ramil Trinidad v4.gslides'
# '2022 Breakthrough Sales Account Planning'/
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 10052022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 1H 08032022.xlsx'
# '2022 MDI Novare PMS Template MANGAHAS, PAULO v1 Yr 2022 30Jan2023_RamilReviewed.xlsx'
# '2022 Sales and GP_v14_delinked - DAO Rev & GP.xlsx'
# '2022 SOs for Validation of PS.xlsx'
# '20230313 Request For Proposal (RFP) - Cloud Modernization for Data Platform v4 (2).xlsx'
# '2023 MDI Novare Budget Template - Product and Sales Operations.xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone (1).xlsx'
# '2023 MDI Novare PMS Template TRINIDAD, RAMIL_1on1SessionDone.xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - FY2024 (Reviewed).xlsx'
# '2024 MDI Novare PMS Template PASCUAL, GABRIELLE QUIRINO - Use for Probationary Goals - with IMFeedback.xlsx'
# '2024 Training and Cert Budget Summary - PendingFinanceNego-Approval.xlsx'
# ...

# %%
# !tree "/content/drive/My Drive/Sudoku-Solver" -L 2
# Out:
# /content/drive/My Drive/Sudoku-Solver
# ├── scripts
# │   └── run_all_tests.py
# ├── src
# │   ├── __init__.py
# │   └── Sudoku-Solver
# └── tests
#     ├── approval_tests.py
#     ├── edge_case_tests.py
#     ├── __init__ (1).py
#     ├── integration_tests.py
#     ├── performance_tests.py
#     ├── property_tests.py
#     ├── solvers.py
#     └── unit_tests.py
#
# 4 directories, 10 files

# %%
# !tree "/content/drive/My Drive/Sudoku-Solver" -L 4
# Out:
# /content/drive/My Drive/Sudoku-Solver
# ├── pyproject.toml
# ├── README.md
# ├── scripts
# │   └── run_all_tests.py
# ├── src
# │   ├── __init__.py
# │   └── Sudoku-Solver
# │       ├── backtracking.py
# │       ├── brute_force.py
# │       ├── __init__.py
# │       ├── pruning.py
# │       ├── utils.py
# │       └── validator.py
# └── tests
#     ├── approval_tests.py
#     ├── edge_case_tests.py
#     ├── __init__ (1).py
#     ├── integration_tests.py
#     ├── performance_tests.py
#     ├── property_tests.py
#     ├── solvers.py
#     └── unit_tests.py
#
# 4 directories, 18 files
